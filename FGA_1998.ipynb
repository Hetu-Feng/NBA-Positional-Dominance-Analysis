# %%
conda install selenium
# Out:
# ...
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2019.07=py37_0
#   - defaults/osx-64::numba==0.44.1=py37h6440ff4_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/hetufeng/anaconda3
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2019.10.16 |                0         131 KB
#     certifi-2019.9.11          |           py37_0         154 KB
#     conda-4.7.12               |           py37_0         3.0 MB
#     openssl-1.1.1d             |       h1de35cc_3         3.4 MB
# ...

# %%
from selenium import webdriver
from pandas import *
import pandas
import numpy as np

#open the stat.nba.com webpage with selenium driver
url = 'https://stats.nba.com/players/traditional/?sort=GP&dir=-1&Season=1998-99&SeasonType=Regular%20Season'

EXE_PATH = '/Users/hetufeng/Downloads/chromedriver'
driver = webdriver.Chrome(executable_path=EXE_PATH)
driver.get(url)
driver.implicitly_wait(100)

# %%
#set year, regular season and present all stats

driver.find_element_by_xpath('/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[22]').click()
driver.find_element_by_xpath('/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[2]/div/div/label/select/option[2]').click()
driver.find_element_by_xpath('/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[3]/div/div/select/option[1]').click()

# %%
#find stats table from the current season
table = driver.find_element_by_class_name('nba-stat-table__overflow')

# %%
#find player name,and fga. added to list
player_names = []
player_stats = []
stats = []
names = []
fga = []
gp = []
minutes = []
fga_98 = []

for line_id, lines in enumerate(table.text.split('\n')):
    if line_id == 0:
        column_names = lines.split(' ')[1:]
    else:
        if line_id % 3 == 2:
            player_names.append(lines)
        if line_id % 3 == 0:
            player_stats.append( [i for i in lines.split(' ')] )
        
names = player_names[:400]

stats = player_stats[:400]

for stat in stats:
    fga.append(float(stat[8]))
    gp.append(float(stat[2]))
    minutes.append(float(stat[5]))
    
    
for i in range(len(fga)):
    fga_98.append([names[i],fga[i], gp[i], minutes[i]])

# %%
fga_98
# Out:
# [['A.C. Green', 5.1, 50.0, 18.5],
#  ['Aaron McKie', 4.7, 50.0, 19.2],
#  ['Allan Houston', 14.1, 50.0, 36.3],
#  ['Alvin Williams', 4.7, 50.0, 21.0],
#  ['Anfernee Hardaway', 14.3, 50.0, 38.9],
#  ['Antonio McDyess', 17.6, 50.0, 38.7],
#  ['Arvydas Sabonis', 9.6, 50.0, 27.0],
#  ['Avery Johnson', 9.2, 50.0, 33.5],
#  ['Bob Sura', 4.2, 50.0, 16.8],
#  ['Bobby Jackson', 7.0, 50.0, 18.8],
#  ['Bryon Russell', 9.4, 50.0, 35.3],
#  ['Calbert Cheaney', 8.3, 50.0, 25.3],
#  ['Cedric Henderson', 9.1, 50.0, 30.4],
#  ['Charles Oakley', 6.5, 50.0, 32.7],
#  ['Charlie Ward', 6.7, 50.0, 31.1],
#  ['Chris Mullin', 7.4, 50.0, 23.5],
#  ['Chuck Person', 5.8, 50.0, 19.8],
#  ['Clifford Robinson', 12.6, 50.0, 34.8],
#  ['Corliss Williamson', 11.1, 50.0, 27.5],
#  ['Dale Davis', 6.0, 50.0, 27.5],
#  ['Damon Stoudamire', 12.6, 50.0, 33.5],
#  ['Dana Barros', 7.4, 50.0, 23.1],
#  ['Danny Ferry', 5.9, 50.0, 21.1],
#  ['Danny Fortson', 7.7, 50.0, 28.4],
#  ['Danny Manning', 7.7, 50.0, 23.7],
# ...
